# %%
# Utilisation des tests
age = int(input("How old are you? "))

while age < 0:
  print("Invalid age")
  age = int(input("How old are you? "))
if age < 18 :
  print('you are a kid')
elif age > 55:
  print('you a senior')
else:
  print('you are an adult')
#
# Out:
# you are an adult
