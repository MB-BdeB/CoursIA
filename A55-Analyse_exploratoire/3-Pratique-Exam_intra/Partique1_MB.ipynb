# %%
# Cell: Chargement et exploration de base de iris.csv
import pandas as pd

df = pd.read_csv("student_mat1.csv")

# Aperçu
print('Taille du jeu :', df.shape)
display(df.head())
# Statistiques descriptives
display(df.describe().T)
# Vérifier valeurs manquantes
print('\nValeurs manquantes par colonne:')
print(df.isna().sum())
# Out:
# Taille du jeu : (395, 11)
# Taille du jeu : (395, 11)
#   school sex   age address     Mjob      Fjob  studytime  absences  G1  G2  G3
# 0    NaN   F  18.0       U  at_home   teacher        NaN         6   5   6   6
# 1     GP   F  17.0       U  at_home     other        2.0         4   5   5   6
# 2     GP   F  15.0       U  at_home     other        2.0        10   7   8  10
# 3     GP   F  15.0       U   health  services        3.0         2  15  14  15
# 4     GP   F  16.0       U    other     other        2.0         4   6  10  10
# Taille du jeu : (395, 11)
#   school sex   age address     Mjob      Fjob  studytime  absences  G1  G2  G3
# 0    NaN   F  18.0       U  at_home   teacher        NaN         6   5   6   6
# 1     GP   F  17.0       U  at_home     other        2.0         4   5   5   6
# 2     GP   F  15.0       U  at_home     other        2.0        10   7   8  10
# 3     GP   F  15.0       U   health  services        3.0         2  15  14  15
# ...
