# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import pandas as pd
import numpy as np
from sklearn import preprocessing
from pandas import read_csv
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# 1. Téléchargez les données de l’ensemble de données DataClustering

# %%
# Load the dataset
df = pd.read_excel('C:\\Users\\bouma12\\VSCode_WorkSpace\\Fonction_travail\\Chapitre7\\DataClustering.xls', sheet_name='data')
df = pd.read_excel('DataClustering.xls', sheet_name='data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Load the dataset
# ----> 2 df = pd.read_excel('C:\\Users\\bouma12\\VSCode_WorkSpace\\Fonction_travail\\Chapitre7\\DataClustering.xls', sheet_name='Data')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
# ...
