# %% [markdown]
# **Chapitre 4 Analyse descriptive**

# %% [markdown]
# Lecturte de la base de donnée Heart

# %%
import pandas as pd

df = pd.read_table("Heart.txt", sep = '\t', header = 0)
print(df.shape)
print(df)
# Out:
# (270, 13)
#      age      sexe type_douleur  pression  cholester sucre electro  taux_max  \
# 0     70  masculin            D       130        322     A       C       109
# 1     67   feminin            C       115        564     A       C       160
# 2     57  masculin            B       124        261     A       A       141
# 3     64  masculin            D       128        263     A       A       105
# 4     74   feminin            B       120        269     A       C       121
# ..   ...       ...          ...       ...        ...   ...     ...       ...
# 265   52  masculin            C       172        199     B       A       162
# 266   44  masculin            B       120        263     A       A       173
# 267   56   feminin            B       140        294     A       C       153
# 268   57  masculin            D       140        192     A       A       148
# 269   67  masculin            D       160        286     A       C       108
#
# ...

# %%
print (df.dtypes)
# Out:
# age               int64
# sexe             object
# type_douleur     object
# pression          int64
# cholester         int64
# sucre            object
# electro          object
# taux_max          int64
# angine           object
# depression      float64
# pic               int64
# vaisseau         object
# coeur            object
# dtype: object

# %%
#print(df.describe().all)
#print(df.describe().T)
print(df.describe().T['mean'])
print(df.info())
# Out:
# age            54.433333
# pression      131.344444
# cholester     249.659259
# taux_max      149.677778
# depression      1.050000
# pic             1.585185
# Name: mean, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           270 non-null    int64
#  1   sexe          270 non-null    object
#  2   type_douleur  270 non-null    object
#  3   pression      270 non-null    int64
#  4   cholester     270 non-null    int64
#  5   sucre         270 non-null    object
#  6   electro       270 non-null    object
#  7   taux_max      270 non-null    int64
#  8   angine        270 non-null    object
#  9   depression    270 non-null    float64
#  10  pic           270 non-null    int64
#  11  vaisseau      270 non-null    object
#  12  coeur         270 non-null    object
# dtypes: float64(1), int64(5), object(7)
# ...

# %%
#print(df.describe().all)
#print(df.describe().T)
print(df.describe().T['mean'])
print(df.info())
# Out:
# age            54.433333
# pression      131.344444
# cholester     249.659259
# taux_max      149.677778
# depression      1.050000
# pic             1.585185
# Name: mean, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           270 non-null    int64
#  1   sexe          270 non-null    object
#  2   type_douleur  270 non-null    object
#  3   pression      270 non-null    int64
#  4   cholester     270 non-null    int64
#  5   sucre         270 non-null    object
#  6   electro       270 non-null    object
#  7   taux_max      270 non-null    int64
#  8   angine        270 non-null    object
#  9   depression    270 non-null    float64
#  10  pic           270 non-null    int64
#  11  vaisseau      270 non-null    object
#  12  coeur         270 non-null    object
# dtypes: float64(1), int64(5), object(7)
# ...

# %%
df.value_counts()
#df.describe(include='all')
# Out:
# age  sexe      type_douleur  pression  cholester  sucre  electro  taux_max  angine  depression  pic  vaisseau  coeur
# 77   masculin  D             125       304        A      C        162       oui     0.0         1    D         presence    1
# 29   masculin  B             130       204        A      C        202       non     0.0         1    A         absence     1
# 34   feminin   B             118       210        A      A        192       non     0.7         1    A         absence     1
#      masculin  A             118       182        A      C        174       non     0.0         1    A         absence     1
# 35   feminin   D             138       183        A      A        182       non     1.4         1    A         absence     1
#                                                                                                                           ..
# ...

# %%
# Import matplotlib and plot the dataframe
import matplotlib.pyplot as plt
df.plot.bar()
# Out:
# <Axes: >

# %%
# Show the mean of each column
df.mean(axis=0, numeric_only=True)
# Out:
# age            54.433333
# pression      131.344444
# cholester     249.659259
# taux_max      149.677778
# depression      1.050000
# pic             1.585185
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# age            55.0
# pression      130.0
# cholester     245.0
# taux_max      153.5
# depression      0.8
# pic             2.0
# dtype: float64

# %%
df.quantile(numeric_only=True)
# Show the standard deviation of each column
# Out:
# age            55.0
# pression      130.0
# cholester     245.0
# taux_max      153.5
# depression      0.8
# pic             2.0
# Name: 0.5, dtype: float64

# %%
df.var(numeric_only=True)
# Show the standard deviation of each column
# Out:
# age             82.975093
# pression       319.037051
# cholester     2671.467107
# taux_max       536.650434
# depression       1.311506
# pic              0.377475
# dtype: float64

# %%
df.std(numeric_only=True)
# Show the standard deviation  of each column
# Out:
# age            9.109067
# pression      17.861608
# cholester     51.686237
# taux_max      23.165717
# depression     1.145210
# pic            0.614390
# dtype: float64

# %%
df.skew(numeric_only=True)
# Show the unbiased skew ecartType  of each column
# Out:
# age          -0.163615
# pression      0.722618
# cholester     1.183721
# taux_max     -0.527737
# depression    1.262893
# pic           0.543151
# dtype: float64

# %%
df.kurtosis(numeric_only=True)
# Show the unbiased kurtosis of each column
# Out:
# age          -0.544815
# pression      0.923097
# cholester     4.895599
# taux_max     -0.103072
# depression    1.759317
# pic          -0.606572
# dtype: float64

# %%
df.hist(bins=10, figsize=(10, 10), layout=(4, 4))
# Show the correlation matrix
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'pression'}>,
#         <Axes: title={'center': 'cholester'}>,
#         <Axes: title={'center': 'taux_max'}>],
#        [<Axes: title={'center': 'depression'}>,
#         <Axes: title={'center': 'pic'}>, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
df.boxplot(column='cholester')
# Show the correlation matrix
# Out:
# <Axes: >
